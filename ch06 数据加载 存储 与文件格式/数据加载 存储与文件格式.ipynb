# %% [markdown]
# # 数据加载 存储与文件格式

# %% [markdown]
# ## 读写文本格式的数据

# %%
# pandas中的解析函数
# read_csv       从文件 URL 文件型对象中加载带分隔符的数据 默认分隔符为逗号
# read_table     从文件 URL 文件型对象中加载带分隔符的数据 默认分隔符为制表符'\t'
# read_fwf       读取定宽列格式数据（没有分隔符）
# read_clipboard 读取剪贴板中的数据 也可以看做是read_table的剪贴板  将网页转化为表格时很有用

# %%
# !type "C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex1.csv"
# Out:
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
# -*- coding: utf-8 -*-
import pandas as pd
import os

file = r"C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex1.csv"

pwd = os.getcwd()
os.chdir(os.path.dirname(file))
df = pd.read_csv(os.path.basename(file))
os.chdir(pwd)

df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_table(os.path.basename(file), sep=',')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# !type "C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex2.csv"
# Out:
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
import pandas
import os

file2 = r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex2.csv'
pwd = os.getcwd()
os.chdir(os.path.dirname(file2))
# name定义列名
pd.read_csv(os.path.basename(file2), names=['a', 'b', 'c', 'd', 'message'])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# index_col 将列放入到索引的位置
names = ['a', 'b', 'c', 'd', 'message']
pd.read_csv(os.path.basename(file2), names=names, index_col='message')
# Out:
#          a   b   c   d
# message
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %%
df.set_index('message', drop=False)
# Out:
#          a   b   c   d message
# message
# hello    1   2   3   4   hello
# world    5   6   7   8   world
# foo      9  10  11  12     foo

# %%
# !type "C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\csv_mindex.csv"
# Out:
# key1,key2,value1,value2
# one,a,1,2
# one,b,3,4
# one,c,5,6
# one,d,7,8
# two,a,9,10
# two,b,11,12
# two,c,13,14
# two,d,15,16

# %%
file3 = r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\csv_mindex.csv'

cdir = os.getcwd()
os.chdir(os.path.dirname(file3))
pd.read_csv(os.path.basename(file3), index_col=['key1', 'key2'])
os.chdir(cdir)

# %% [markdown]
# #### 有些表格不是用弧顶的分隔符去分割字符的（比如空白符或其他模式）

# %%
list(open(r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex3.txt'))
# Out:
# ['            A         B         C\n',
#  'aaa -0.264438 -1.026059 -0.619500\n',
#  'bbb  0.927272  0.302904 -0.032399\n',
#  'ccc -0.264273 -0.386314 -0.217601\n',
#  'ddd -0.871858 -0.348382  1.100491\n']

# %%
pd.read_csv(r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex3.txt', sep='\s+', encoding='gbk',engine='python')
# Out:
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491

# %% [markdown]
# #### 处理异形文件格式

# %%
# !type "C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex4.csv"
# Out:
# # hey!
# a,b,c,d,message
# # just wanted to make things more difficult for you
# # who reads CSV files with computers, anyway?
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
# 跳过第一行 第三行和第四行数据
pd.read_csv(r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex4.csv', skiprows=[0, 2, 3], encoding='utf-8', engine='python')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# #### 缺失值处理

# %%
# !type "C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex5.csv"
# Out:
# something,a,b,c,d,message
# one,1,2,3,4,NA
# two,5,6,,8,world
# three,9,10,11,12,foo

# %%
# 确实数据要么没有 要么用某个标记值表示 如NA -1.#IND 以及NULL
pd.read_csv(r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex5.csv', encoding='utf-8', engine='python')
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
pd.read_csv(r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex5.csv', na_values=['NULL'], encoding='utf-8', engine='python')
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
# 可以用字典为各列指定不同的NA标记值
sentinels = {'message': ['foo', 'NA'], 'something': ['two']}
pd.read_csv(r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex5.csv', na_values=sentinels, encoding='utf-8', engine='python')
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       NaN  5   6   NaN   8   world
# 2     three  9  10  11.0  12     NaN

# %% [markdown]
# ### 逐块读取文本文件

# %%
result = pd.read_csv(r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex6.csv', na_values=sentinels, encoding='utf-8', engine='python')

# %%
# 如果只想读取几行 可以设置nrows
pd.read_csv(r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex6.csv', nrows=5, encoding='utf-8', engine='python')
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q

# %%
# 要逐块的读取文件 需要设置chunksize行数
chunker = pd.read_csv(r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex6.csv', chunksize=1000, encoding='utf-8', engine='python')
tot = pd.Series([])
for n in chunker:
    tot = tot.add(n['key'].value_counts(), fill_value=0)

tot = tot.sort_values(ascending=False)
tot[:10]
# Out:
# E    368.0
# X    364.0
# L    346.0
# O    343.0
# Q    340.0
# M    338.0
# J    337.0
# F    335.0
# K    334.0
# H    330.0
# dtype: float64

# %% [markdown]
# ### 将数据写出到文本格式

# %%
data = pd.read_csv(r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex5.csv', encoding='utf-8', engine='python')
data
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
# DataFrame的to_csv方法
data.to_csv(r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\ch06 数据加载 存储 与文件格式\ex5.csv')

# %%
import sys
data.to_csv(sys.stdout, sep='|') # sep 设置分隔符
# Out:
# |something|a|b|c|d|message
# 0|one|1|2|3.0|4|
# 1|two|5|6||8|world
# 2|three|9|10|11.0|12|foo

# %%
data.to_csv(sys.stdout, na_rep='NULL') # 缺失值设置
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,NULL
# 1,two,5,6,NULL,8,world
# 2,three,9,10,11.0,12,foo

# %%
data.to_csv(sys.stdout, index=False, header=False) # 行列标签 禁用
# Out:
# one,1,2,3.0,4,
# two,5,6,,8,world
# three,9,10,11.0,12,foo

# %%
data.to_csv(sys.stdout, index=False, columns=['a', 'b', 'c'])
# Out:
# a,b,c
# 1,2,3.0
# 5,6,
# 9,10,11.0

# %% [markdown]
# ### 手工处理分隔符

# %%
# !type "C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex7.csv"
# Out:
# "a","b","c"
# "1","2","3"
# "1","2","3"

# %%
# 单字符分割符文件
import csv
f = open(r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex7.csv')
reader = csv.reader(f)
for line in reader:
    print(line)
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']

# %%
lines = list(csv.reader(open(r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex7.csv')))

# %%
header, values = line[0], line[1:]
data_dict = {h:v for h,v in zip(header, zip(*values))}
data_dict
# Out:
# {'1': ('2', '3')}

# %%
# csv文件格式很多 定义csv.Dialect的子类 即可定义出新格式
import csv 
f = open(r"C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\ex7.csv")
reader = csv.reader(f)

class my_dialect(csv.Dialect):
    lineterminator = '\n' # 用于写操作的行结束符
    delimiter= ';' # 用于分割字段的单字符串
    quotechar= '"' # 由于带有特殊字符的字段的引用符号 默认为“"”
    quoting = csv.QUOTE_MINIMAL # 引用约定

reader = csv.reader(f, dialect=my_dialect)
lines = list(reader)
header, values = lines[0], lines[1:]

data_dict = {h:v for h,v in zip(header, zip(*values))}
data_dict
# Out:
# {'a,"b","c"': ('1,"2","3"', '1,"2","3"')}

# %% [markdown]
# #### 手工输出分隔符文件

# %%
with open('mydata.csv', 'w') as f:
    writer = csv.writer(f, dialect=my_dialect)
    writer.writerow(('one', 'two', 'three'))
    writer.writerow(('1', '2', '3'))
    writer.writerow(('4', '5', '6'))
    writer.writerow(('7', '8', '9'))

# %% [markdown]
# ### JSON数据

# %%
import json
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38,
               "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""
result = json.loads(obj) # 将json string 转化为Python形式
result
# Out:
# {'name': 'Wes',
#  'pet': None,
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'siblings': [{'age': 30, 'name': 'Scott', 'pets': ['Zeus', 'Zuko']},
#   {'age': 38, 'name': 'Katie', 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
asjson = json.dumps(result)

# %%
siblings = pd.DataFrame(result['siblings'], columns=['name', 'age'])
siblings
# Out:
#     name  age
# 0  Scott   30
# 1  Katie   38

# %% [markdown]
# ### XML和HTML：Web信息收集

# %% [markdown]
# #### 读写HTML和XML格式数据 许多网站将数据放入到HTML表格中以便浏览器中查看

# %%
tables = pd.read_html(r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\examples\fdic_failed_bank_list.html')
len(tables)
failures = tables[0] # 去除[]
failures.head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %%
failures['Closing Date']
# Out:
# 0      September 23, 2016
# 1         August 19, 2016
# 2             May 6, 2016
# 3          April 29, 2016
# 4          March 11, 2016
# 5         October 2, 2015
# 6         October 2, 2015
# 7           July 10, 2015
# 8             May 8, 2015
# 9       February 27, 2015
# 10      February 13, 2015
# 11       January 23, 2015
# 12       January 16, 2015
# 13      December 19, 2014
# 14       November 7, 2014
# 15       October 24, 2014
# 16       October 17, 2014
# 17          July 25, 2014
# 18          July 18, 2014
# 19          June 27, 2014
# 20          June 20, 2014
# 21          June 20, 2014
# 22           May 30, 2014
# 23           May 23, 2014
# 24           May 16, 2014
# 25         April 25, 2014
# 26      February 28, 2014
# 27      February 28, 2014
# 28       January 31, 2014
# 29       January 24, 2014
#               ...
# 517           May 9, 2008
# 518         March 7, 2008
# 519      January 25, 2008
# 520       October 4, 2007
# 521    September 28, 2007
# ...

# %%
close_timestamps = pd.to_datetime(failures['Closing Date'])
close_timestamps
# Out:
# 0     2016-09-23
# 1     2016-08-19
# 2     2016-05-06
# 3     2016-04-29
# 4     2016-03-11
# 5     2015-10-02
# 6     2015-10-02
# 7     2015-07-10
# 8     2015-05-08
# 9     2015-02-27
# 10    2015-02-13
# 11    2015-01-23
# 12    2015-01-16
# 13    2014-12-19
# 14    2014-11-07
# 15    2014-10-24
# 16    2014-10-17
# 17    2014-07-25
# 18    2014-07-18
# 19    2014-06-27
# 20    2014-06-20
# 21    2014-06-20
# 22    2014-05-30
# 23    2014-05-23
# 24    2014-05-16
# 25    2014-04-25
# 26    2014-02-28
# 27    2014-02-28
# 28    2014-01-31
# 29    2014-01-24
#          ...
# 517   2008-05-09
# 518   2008-03-07
# 519   2008-01-25
# 520   2007-10-04
# 521   2007-09-28
# 522   2007-02-02
# 523   2004-06-25
# 524   2004-03-19
# 525   2004-03-12
# 526   2004-02-14
# 527   2003-11-14
# 528   2003-05-09
# 529   2003-02-07
# 530   2002-12-17
# 531   2002-11-08
# 532   2002-09-30
# 533   2002-06-27
# 534   2002-06-26
# 535   2002-03-28
# 536   2002-03-01
# 537   2002-02-07
# ...

# %%
close_timestamps.dt.year.value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2015      8
# 2016      5
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: Closing Date, dtype: int64

# %% [markdown]
# ### Parsing XML with lxml.objectify

# %%
from lxml import objectify

path = r'C:\Users\Administrator\Desktop\计算机入门学习\支线：Python for Data Analysis\pydata-book-2nd-edition\pydata-book-2nd-edition\datasets\mta_perf\Performance_MNR.xml'
parsed = objectify.parse(open(path))
print(parsed)
root = parsed.getroot()
print(root)

# %%
data = []

skip_fields = ['PARENT_SEQ', 'INDICATOR_SEQ',
               'DESIRED_CHANGE', 'DECIMAL_PLACES']

for elt in root.INDICATOR:
    el_data = {}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)
    
data
# Out:
# [{'AGENCY_NAME': 'Metro-North Railroad',
#   'CATEGORY': 'Service Indicators',
#   'DESCRIPTION': 'Percent of commuter trains that arrive at their destinations within 5 minutes and 59 seconds of the scheduled time. West of Hudson services include the Pascack Valley and Port Jervis lines. Metro-North Railroad contracts with New Jersey Transit to operate service on these lines.\n',
#   'FREQUENCY': 'M',
#   'INDICATOR_NAME': 'On-Time Performance (West of Hudson)',
#   'INDICATOR_UNIT': '%',
#   'MONTHLY_ACTUAL': 96.9,
#   'MONTHLY_TARGET': 95.0,
#   'PERIOD_MONTH': 1,
#   'PERIOD_YEAR': 2008,
#   'YTD_ACTUAL': 96.9,
#   'YTD_TARGET': 95.0},
#  {'AGENCY_NAME': 'Metro-North Railroad',
#   'CATEGORY': 'Service Indicators',
# ...

# %%
perf = pd.DataFrame(data)
perf.head()
# Out:
#             AGENCY_NAME            CATEGORY  \
# 0  Metro-North Railroad  Service Indicators
# 1  Metro-North Railroad  Service Indicators
# 2  Metro-North Railroad  Service Indicators
# 3  Metro-North Railroad  Service Indicators
# 4  Metro-North Railroad  Service Indicators
#
#                                          DESCRIPTION FREQUENCY  \
# 0  Percent of commuter trains that arrive at thei...         M
# 1  Percent of commuter trains that arrive at thei...         M
# 2  Percent of commuter trains that arrive at thei...         M
# 3  Percent of commuter trains that arrive at thei...         M
# 4  Percent of commuter trains that arrive at thei...         M
#
#                          INDICATOR_NAME INDICATOR_UNIT MONTHLY_ACTUAL  \
# 0  On-Time Performance (West of Hudson)              %           96.9
# 1  On-Time Performance (West of Hudson)              %             95
# 2  On-Time Performance (West of Hudson)              %           96.9
# ...

# %%
from io import StringIO
tag = '<a href="http://www.google.com">Google</a>'
root = objectify.parse(StringIO(tag)).getroot()

# %%
root
root.get('href')
root.text
# Out:
# 'Google'

# %% [markdown]
# ### Reading Microsoft Excel Files

# %%
xlsx = pd.ExcelFile('examples/ex1.xlsx')

# %%
pd.read_excel(xlsx, 'Sheet1')

# %%
frame = pd.read_excel('examples/ex1.xlsx', 'Sheet1')
frame

# %%
frame.to_excel('examples/ex2.xlsx')

# %% [markdown]
# ## 使用数据库

# %% [markdown]
# ### SQLite3

# %%
import pandas as pd
import sqlite3
# 创建表操作
query = """
CREATE TABLE test
(a VARCHAR(20), b VARCHAR(20),
 c REAL,        d INTEGER
);"""
con = sqlite3.connect('mydata.sqlite') # 创建数据库连接
con.execute(query) # 执行创建表操作
con.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-6-4d287667139b> in <module>()
#       7 );"""
#       8 con = sqlite3.connect('mydata.sqlite')
# ----> 9 con.execute(query)
#      10 con.commit()
#
# OperationalError: table test already exists

# %%
# 创建数据
data = [('Atlanta', 'Georgia', 1.25, 6),     
        ('Tallahassee', 'Florida', 2.6, 3),
        ('Sacramento', 'California', 1.7, 5)]
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)" # 创建插入表操作
con.executemany(stmt, data) # 执行插入表操作和数据
con.commit()

# %%
cursor = con.execute('select * from test') # 执行从数据库中读取表
rows = cursor.fetchall() # 
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5),
#  ('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
cursor.description
pd.DataFrame(rows, columns=[x[0] for x in cursor.description])
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5
# 3      Atlanta     Georgia  1.25  6
# 4  Tallahassee     Florida  2.60  3
# 5   Sacramento  California  1.70  5

# %%
import sqlalchemy as sqla
db = sqla.create_engine('sqlite:///mydata.sqlite')
pd.read_sql('select * from test', db)
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5
# 3      Atlanta     Georgia  1.25  6
# 4  Tallahassee     Florida  2.60  3
# 5   Sacramento  California  1.70  5
